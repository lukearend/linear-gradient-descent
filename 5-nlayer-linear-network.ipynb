# %%
import numpy as np
from functools import reduce, partial
import pickle

# %%
def rand_W(M, N):
    return np.random.randn(M, N) / np.sqrt(N)

def orth_W(M, N):
    W = np.random.randn(N, N)
    Q, R = np.linalg.qr(W)
    return Q[:M, :N]

def init_weights(Ns, orth=False):
    Ws = []
    for M, N in zip(Ns[1:], Ns[:-1]):
        W = orth_W(M, N) if orth else rand_W(M, N)
        Ws.append(W)
    return Ws

# %%
def compose(Ws):
    return reduce(np.dot, Ws[::-1])

def forward(Ws, X):
    return X @ compose(Ws).T

def backward(Ws, C11, C31, lr):
    dLdg = compose(Ws) @ C11 - C31
    for i, W in enumerate(Ws):
        if i == 0:
            dLdW = compose(Ws[1:]).T @ dLdg
        elif i == len(Ws) - 1:
            dLdW = dLdg @ compose(Ws[:-1]).T
        else:
            dLdW = compose(Ws[i + 1:]).T @ dLdg @ compose(Ws[:i]).T
        W -= lr * dLdW

# %%
class Network:
    def __init__(self, Ws, X, Y):
        self.Ws = Ws
        self.C11 = X.T @ X / len(X)
        self.C31 = Y.T @ X / len(X)

    def map(self, X):
        return forward(self.Ws, X)

    def loss(self, X, Y):
        return np.mean((Y - self.map(X)) ** 2)

    def update(self, lr):
        return backward(self.Ws, self.C11, self.C31, lr)

# %%
with open('mnist.pkl', 'rb') as f:
    mnist = pickle.load(f)
X = mnist['X'].astype('float32')
Y = mnist['Y'].astype('float32')
X -= X.mean(axis=0)
std = X.std(axis=0)
std[std == 0] = 1
X /= std
Y /= Y.std(axis=0)
train = np.arange(50000)
test = np.arange(50000, 60000)

# %%
np.random.seed(0)
N = [784] + 100 * [100] + [10]
W1 = init_weights(N)
W2 = init_weights(N, orth=True)
g1 = Network(W1, X[train], Y[train])
g2 = Network(W2, X[train], Y[train])

# %%
for i in range(100):
    if i % 1 == 0:
        print(f"{i}: g1 train {g1.loss(X[train], Y[train]):.4f}, valid {g1.loss(X[test], Y[test]):.4f};",
              f"g2 train {g2.loss(X[train], Y[train]):.4f} valid {g2.loss(X[test], Y[test]):.4f}")
    g1.update(0.00005)
    g2.update(0.001)
    i += 1
# Out:
# 0: g1 train 2.2702, valid 2.1648; g2 train 2.0891 valid 1.9865
# 1: g1 train 1.5745, valid 1.5285; g2 train 1.6279 valid 1.5437
# 2: g1 train 1.3667, valid 1.3406; g2 train 1.4212 valid 1.3476
# 3: g1 train 1.2772, valid 1.2581; g2 train 1.2975 valid 1.2315
# 4: g1 train 1.2340, valid 1.2186; g2 train 1.2127 valid 1.1527
# 5: g1 train 1.2079, valid 1.1951; g2 train 1.1501 valid 1.0949
# 6: g1 train 1.1900, valid 1.1788; g2 train 1.1016 valid 1.0503
# 7: g1 train 1.1766, valid 1.1666; g2 train 1.0627 valid 1.0146
# 8: g1 train 1.1663, valid 1.1572; g2 train 1.0306 valid 0.9853
# 9: g1 train 1.1580, valid 1.1496; g2 train 1.0036 valid 0.9606
# 10: g1 train 1.1512, valid 1.1433; g2 train 0.9806 valid 0.9395
# 11: g1 train 1.1454, valid 1.1380; g2 train 0.9607 valid 0.9213
# 12: g1 train 1.1404, valid 1.1334; g2 train 0.9432 valid 0.9053
# 13: g1 train 1.1361, valid 1.1294; g2 train 0.9278 valid 0.8911
# 14: g1 train 1.1323, valid 1.1259; g2 train 0.9141 valid 0.8785
# 15: g1 train 1.1289, valid 1.1227; g2 train 0.9017 valid 0.8671
# 16: g1 train 1.1258, valid 1.1199; g2 train 0.8905 valid 0.8568
# 17: g1 train 1.1230, valid 1.1173; g2 train 0.8804 valid 0.8475
# 18: g1 train 1.1205, valid 1.1150; g2 train 0.8712 valid 0.8389
# 19: g1 train 1.1182, valid 1.1128; g2 train 0.8627 valid 0.8311
# 20: g1 train 1.1161, valid 1.1108; g2 train 0.8548 valid 0.8238
# 21: g1 train 1.1141, valid 1.1089; g2 train 0.8476 valid 0.8171
# 22: g1 train 1.1122, valid 1.1072; g2 train 0.8409 valid 0.8109
# 23: g1 train 1.1105, valid 1.1056; g2 train 0.8347 valid 0.8051
# 24: g1 train 1.1089, valid 1.1041; g2 train 0.8288 valid 0.7997
# 25: g1 train 1.1074, valid 1.1027; g2 train 0.8234 valid 0.7946
# 26: g1 train 1.1060, valid 1.1013; g2 train 0.8183 valid 0.7898
# 27: g1 train 1.1046, valid 1.1000; g2 train 0.8135 valid 0.7853
# 28: g1 train 1.1033, valid 1.0988; g2 train 0.8089 valid 0.7811
# 29: g1 train 1.1021, valid 1.0976; g2 train 0.8046 valid 0.7771
# 30: g1 train 1.1010, valid 1.0965; g2 train 0.8006 valid 0.7733
# 31: g1 train 1.0998, valid 1.0955; g2 train 0.7967 valid 0.7697
# 32: g1 train 1.0988, valid 1.0945; g2 train 0.7931 valid 0.7663
# 33: g1 train 1.0978, valid 1.0935; g2 train 0.7896 valid 0.7631
# 34: g1 train 1.0968, valid 1.0926; g2 train 0.7863 valid 0.7600
# 35: g1 train 1.0959, valid 1.0917; g2 train 0.7832 valid 0.7570
# 36: g1 train 1.0950, valid 1.0908; g2 train 0.7802 valid 0.7542
# 37: g1 train 1.0941, valid 1.0899; g2 train 0.7773 valid 0.7515
# 38: g1 train 1.0932, valid 1.0891; g2 train 0.7745 valid 0.7489
# 39: g1 train 1.0924, valid 1.0883; g2 train 0.7719 valid 0.7464
# 40: g1 train 1.0916, valid 1.0876; g2 train 0.7694 valid 0.7441
# 41: g1 train 1.0909, valid 1.0868; g2 train 0.7669 valid 0.7418
# 42: g1 train 1.0901, valid 1.0861; g2 train 0.7646 valid 0.7396
# 43: g1 train 1.0894, valid 1.0854; g2 train 0.7624 valid 0.7375
# 44: g1 train 1.0887, valid 1.0847; g2 train 0.7602 valid 0.7354
# 45: g1 train 1.0880, valid 1.0841; g2 train 0.7581 valid 0.7335
# 46: g1 train 1.0874, valid 1.0834; g2 train 0.7561 valid 0.7316
# 47: g1 train 1.0867, valid 1.0828; g2 train 0.7542 valid 0.7297
# 48: g1 train 1.0861, valid 1.0822; g2 train 0.7523 valid 0.7280
# 49: g1 train 1.0855, valid 1.0816; g2 train 0.7505 valid 0.7263
# 50: g1 train 1.0849, valid 1.0810; g2 train 0.7487 valid 0.7246
# 51: g1 train 1.0843, valid 1.0804; g2 train 0.7470 valid 0.7230
# 52: g1 train 1.0837, valid 1.0798; g2 train 0.7453 valid 0.7214
# 53: g1 train 1.0832, valid 1.0793; g2 train 0.7437 valid 0.7199
# 54: g1 train 1.0826, valid 1.0787; g2 train 0.7422 valid 0.7185
# 55: g1 train 1.0821, valid 1.0782; g2 train 0.7407 valid 0.7171
# 56: g1 train 1.0815, valid 1.0777; g2 train 0.7392 valid 0.7157
# 57: g1 train 1.0810, valid 1.0772; g2 train 0.7378 valid 0.7143
# 58: g1 train 1.0805, valid 1.0767; g2 train 0.7364 valid 0.7130
# 59: g1 train 1.0800, valid 1.0762; g2 train 0.7351 valid 0.7118
# 60: g1 train 1.0795, valid 1.0757; g2 train 0.7338 valid 0.7105
# 61: g1 train 1.0790, valid 1.0752; g2 train 0.7325 valid 0.7093
# 62: g1 train 1.0786, valid 1.0747; g2 train 0.7313 valid 0.7082
# 63: g1 train 1.0781, valid 1.0742; g2 train 0.7300 valid 0.7070
# 64: g1 train 1.0776, valid 1.0738; g2 train 0.7289 valid 0.7059
# 65: g1 train 1.0772, valid 1.0733; g2 train 0.7277 valid 0.7048
# 66: g1 train 1.0767, valid 1.0729; g2 train 0.7266 valid 0.7038
# 67: g1 train 1.0763, valid 1.0724; g2 train 0.7255 valid 0.7027
# 68: g1 train 1.0759, valid 1.0720; g2 train 0.7244 valid 0.7017
# 69: g1 train 1.0754, valid 1.0716; g2 train 0.7234 valid 0.7008
# 70: g1 train 1.0750, valid 1.0712; g2 train 0.7224 valid 0.6998
# 71: g1 train 1.0746, valid 1.0707; g2 train 0.7214 valid 0.6988
# 72: g1 train 1.0742, valid 1.0703; g2 train 0.7204 valid 0.6979
# 73: g1 train 1.0738, valid 1.0699; g2 train 0.7194 valid 0.6970
# 74: g1 train 1.0734, valid 1.0695; g2 train 0.7185 valid 0.6961
# 75: g1 train 1.0730, valid 1.0691; g2 train 0.7176 valid 0.6953
# 76: g1 train 1.0726, valid 1.0687; g2 train 0.7167 valid 0.6944
# 77: g1 train 1.0722, valid 1.0684; g2 train 0.7158 valid 0.6936
# 78: g1 train 1.0719, valid 1.0680; g2 train 0.7149 valid 0.6928
# 79: g1 train 1.0715, valid 1.0676; g2 train 0.7141 valid 0.6920
# 80: g1 train 1.0711, valid 1.0672; g2 train 0.7132 valid 0.6912
# 81: g1 train 1.0707, valid 1.0668; g2 train 0.7124 valid 0.6905
# 82: g1 train 1.0704, valid 1.0665; g2 train 0.7116 valid 0.6897
# 83: g1 train 1.0700, valid 1.0661; g2 train 0.7109 valid 0.6890
# 84: g1 train 1.0697, valid 1.0658; g2 train 0.7101 valid 0.6882
# 85: g1 train 1.0693, valid 1.0654; g2 train 0.7093 valid 0.6875
# 86: g1 train 1.0690, valid 1.0651; g2 train 0.7086 valid 0.6868
# 87: g1 train 1.0686, valid 1.0647; g2 train 0.7079 valid 0.6861
# 88: g1 train 1.0683, valid 1.0644; g2 train 0.7071 valid 0.6855
# 89: g1 train 1.0679, valid 1.0640; g2 train 0.7064 valid 0.6848
# 90: g1 train 1.0676, valid 1.0637; g2 train 0.7057 valid 0.6842
# 91: g1 train 1.0673, valid 1.0633; g2 train 0.7051 valid 0.6835
# 92: g1 train 1.0670, valid 1.0630; g2 train 0.7044 valid 0.6829
# 93: g1 train 1.0666, valid 1.0627; g2 train 0.7037 valid 0.6823
# 94: g1 train 1.0663, valid 1.0624; g2 train 0.7031 valid 0.6817
# 95: g1 train 1.0660, valid 1.0620; g2 train 0.7024 valid 0.6811
# 96: g1 train 1.0657, valid 1.0617; g2 train 0.7018 valid 0.6805
# 97: g1 train 1.0654, valid 1.0614; g2 train 0.7012 valid 0.6799
# 98: g1 train 1.0650, valid 1.0611; g2 train 0.7006 valid 0.6793
# 99: g1 train 1.0647, valid 1.0608; g2 train 0.7000 valid 0.6788
